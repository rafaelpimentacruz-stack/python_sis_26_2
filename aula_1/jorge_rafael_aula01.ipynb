# %% [markdown]
# <a href="https://colab.research.google.com/github/rafaelpimentacruz-stack/python_sis_26_2/blob/main/aula_1/jorge_rafael_aula01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# AULA 1

# %%
#Crie 4 variaveis, utilizando os 4 tipos de dados#

nome_personagem = "Jorge"     #Nome do personagem que identificará ele
idade = 28                    #Será usado para ganho de experiencia
altura_personagem = 1.82      #Será usado para biografia de aposentadoria
armadura = True               #Será usado para quando for ter jogo

#Criando uma class

class Jorge:
  """
    Personagem da elite do exercito brasileiro, especializado em resgate de refens,
     possui habilidades especial com armas, desde armas brancas a armas atomicas
     """
help(Jorge)
# Out:
# Help on class Jorge in module __main__:
#
# class Jorge(builtins.object)
#  |  Personagem da elite do exercito brasileiro, especializado em resgate de refens,
#  |   possui habilidades especial com armas, desde armas brancas a armas atomicas
#  |
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables
#  |
#  |  __weakref__
#  |      list of weak references to the object
